# %%
# %load_ext autoreload
# %autoreload 2

import compression as C
import time
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nslices =  -1

ac3 = C.Util.load_data('ac3', nslices)
#ac3 = ac3[:,0:720,0:720]
print ac3.shape
imshow(ac3[0])
# Out:
# (75, 1024, 1024)

# %%
results = C.Util.run_experiments(data=np.copy(ac3), N=1, com_alg=[C.VARIABLE_ENCODING], enc_alg=[C.NE], verbose=True)
#C.Util.plot(results[0], results[1], results[2], results[3], results[4], results[5], results[6], results[7], results[8], results[9], results[10])
