# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import compression as C
import nibabel
import numpy as np

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/d/nolearn/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
a = nibabel.load('/tmp/aparc+aseg.mgz')

# %%
np.save('/home/d/data/danielbrain.npy', a.get_data())

# %%
c = C.Util.load_data('cylinder', N=1)

# %%
a = C.Util.load_data('ac3', N=1)

# %%
plt.figure(figsize=(10,10))
plt.axis('off')
imshow(C.Util.colorize(c[0]), interpolation='nearest')
plt.savefig('/home/d/Projects/cs222finalproject/PAPER/gfx/cyl.png', bbox_inches='tight')

# %%
plt.figure(figsize=(10,10))
plt.axis('off')
imshow(C.Util.colorize(a[0]), interpolation='nearest')
plt.savefig('/home/d/Projects/cs222finalproject/PAPER/gfx/ac3.png', bbox_inches='tight')
