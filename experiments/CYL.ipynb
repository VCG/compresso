# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import compression as C
from matplotlib.pyplot import imshow

# %matplotlib inline
# Out:
# /home/d/nolearn/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Load data
data = C.Util.load_data('cylinder')
# Fritz only
#data = C.Util.load_data('cylinder', -1, '/Volumes/FFRITZ/cs222/cylinder/rhoana/')
imshow(C.Util.colorize(data[0]))

# %%
# SETUP

# Iterations
N = 5

# DEFAULT --------------------------------------------------
# Compression methods
def_coms = [
     C.BOCKWURST,
     C.LZMA,
    C.ZLIB
]

# Encoding methods
def_encs = [
    C.NE,
    C.NG,
    C.RLE
]

# ALL ------------------------------------------------------
# compression methods
all_coms = [
    C.BOCKWURST,
    # C.BROTLI,
    C.BZ2,
    C.JPEG2000,
    C.LZ78,
   # C.LZF,
    C.LZMA,
    C.LZO,
    C.LZW,
    C.PNG,
    C.X264,
    C.ZLIB,
    # C.ZOPFLI,
    C.ZSTD
]

# encoding methods
all_encs = [
    C.NE,
    C.RLE,
    C.NG,
    C.BOCKWURST
]

# ENCODING ONLY -------------------------------------------
# Compression methods
enc_only_coms = [
    C.NC
]

# encoding methods
enc_only_encs = [
    C.RLE,
    C.NG,
    C.BOCKWURST
]

# %%
# RUN: default
results_default = C.Util.run_experiments(data=data, N=N, com_alg=def_coms, enc_alg=def_encs, verbose=True)
# Out:
# (300, 2048, 2048) (300, 2048, 2048) Bockwurst
# > NE + Bockwurst
# Compression Method: Bockwurst
# Encoding Method: NE
# Input Size: 10066.3296 MB
# Output Size: 11.265152 MB
# Ratio: 893.581338272
# Total Compression Speed [MB/s]: 28.156396519
# Total Decompression Speed [MB/s]: 16.5909610521
# Compression (Only) Speed [MB/s]: 28.1563969133
# Decompression (Only) Speed [MB/s]: 16.5909610847
# Encoding Speed [MB/s]: 2010535547.93
# Decoding Speed [MB/s]: 8444249301.32
#
# (300, 2048, 2048) (1258291200,)
# (300, 2048, 2048) (300, 2048, 2048) LZMA
# > NE + LZMA
# Compression Method: LZMA
# Encoding Method: NE
# Input Size: 10066.3296 MB
# Output Size: 29.890924 MB
# Ratio: 336.768766332
# Total Compression Speed [MB/s]: 8.82070559691
# Total Decompression Speed [MB/s]: 229.062981284
# Compression (Only) Speed [MB/s]: 8.82070562824
# Decompression (Only) Speed [MB/s]: 229.062986255
# Encoding Speed [MB/s]: 2483602735.68
# Decoding Speed [MB/s]: 10555311626.6
#
# (300, 2048, 2048) (1258291200,)
# (300, 2048, 2048) (300, 2048, 2048) LZMA
# > Neuroglancer + LZMA
# Compression Method: LZMA
# Encoding Method: Neuroglancer
# Input Size: 10066.3296 MB
# Output Size: 20.7874 MB
# Ratio: 484.251498504
# Total Compression Speed [MB/s]: 19.1145605179
# Total Decompression Speed [MB/s]: 65.0093602733
# Compression (Only) Speed [MB/s]: 45.6100053672
# Decompression (Only) Speed [MB/s]: 3045.86382221
# Encoding Speed [MB/s]: 32.9043430963
# Decoding Speed [MB/s]: 66.4271473465
#
# (300, 2048, 2048) (300, 2048, 2048)
# (300, 2048, 2048) (300, 2048, 2048) LZMA
# > RLE + LZMA
# Compression Method: LZMA
# Encoding Method: RLE
# Input Size: 10066.3296 MB
# Output Size: 12.104628 MB
# Ratio: 831.609992476
# Total Compression Speed [MB/s]: 31.7670033244
# Total Decompression Speed [MB/s]: 266.594602628
# Compression (Only) Speed [MB/s]: 40.748370298
# Decompression (Only) Speed [MB/s]: 4189.92050268
# Encoding Speed [MB/s]: 144.126569878
# Decoding Speed [MB/s]: 284.710018976
#
# (300, 2048, 2048) (300, 2048, 2048)
# (300, 2048, 2048) (300, 2048, 2048) Zlib
# ==================================================
# WARNING! ONLY 50 SLICES ARE GIVEN TO ZLIB
# ==================================================
# > NE + Zlib
# Compression Method: Zlib
# Encoding Method: NE
# Input Size: 1677.7216 MB
# Output Size: 12.055958 MB
# Ratio: 139.161201457
# Total Compression Speed [MB/s]: 120.403435838
# Total Decompression Speed [MB/s]: 725.36886214
# Compression (Only) Speed [MB/s]: 120.403479101
# Decompression (Only) Speed [MB/s]: 725.369161227
# Encoding Speed [MB/s]: 335089257.989
# Decoding Speed [MB/s]: 1759218604.44
#
# (50, 2048, 2048) (209715200,)
# (300, 2048, 2048) (300, 2048, 2048) Zlib
# ==================================================
# WARNING! ONLY 50 SLICES ARE GIVEN TO ZLIB
# ==================================================
# > Neuroglancer + Zlib
# Compression Method: Zlib
# Encoding Method: Neuroglancer
# Input Size: 1677.7216 MB
# Output Size: 5.506775 MB
# Ratio: 304.664999024
# Total Compression Speed [MB/s]: 50.2590850847
# Total Decompression Speed [MB/s]: 214.611180785
# Compression (Only) Speed [MB/s]: 999.424850739
# Decompression (Only) Speed [MB/s]: 7614.13223936
# Encoding Speed [MB/s]: 52.9203437657
# Decoding Speed [MB/s]: 220.835632146
#
# (50, 2048, 2048) (50, 2048, 2048)
# (300, 2048, 2048) (300, 2048, 2048) Zlib
# ==================================================
# WARNING! ONLY 50 SLICES ARE GIVEN TO ZLIB
# ==================================================
# > RLE + Zlib
# Compression Method: Zlib
# Encoding Method: RLE
# Input Size: 1677.7216 MB
# Output Size: 6.301024 MB
# Ratio: 266.261737775
# Total Compression Speed [MB/s]: 152.708188579
# Total Decompression Speed [MB/s]: 286.523427821
# Compression (Only) Speed [MB/s]: 1299.87328323
# Decompression (Only) Speed [MB/s]: 11798.3240578
# Encoding Speed [MB/s]: 173.036379323
# Decoding Speed [MB/s]: 293.654864278
#
# (50, 2048, 2048) (50, 2048, 2048)

# %%
# RUN: all
results_all = C.Util.run_experiments(data=data, N=N, com_alg=all_coms, enc_alg=all_encs, verbose=True)
# Out:
# (300, 2048, 2048) (300, 2048, 2048) Bockwurst

# %%
# RUN: encoding only
results_enc_only = C.Util.run_experiments(data=data, N=N, com_alg=enc_only_coms, enc_alg=enc_only_encs, verbose=True)

# %%
# PLOT: default

C.Util.plot(
    results_default['methods'],
    results_default['bytes'],
    results_default['ratios'],
    results_default['total_comp_speed'],
    results_default['total_comp_speed_std'],
    results_default['total_decomp_speed'],
    results_default['total_decomp_speed_std'],
    'cyl',
    bw=True
)

# %%
# PLOT: all

C.Util.plot(
    results_all['methods'],
    results_all['bytes'],
    results_all['ratios'],
    results_all['total_comp_speed'],
    results_all['total_comp_speed_std'],
    results_all['total_decomp_speed'],
    results_all['total_decomp_speed_std'],
    'cyl',
    bw=True
)

# %%
# Plot results

C.Util.plot(
    results_enc_only['methods'],
    results_enc_only['bytes'],
    results_enc_only['ratios'],
    results_enc_only['total_comp_speed'],
    results_enc_only['total_comp_speed_std'],
    results_enc_only['total_decomp_speed'],
    results_enc_only['total_decomp_speed_std'],
    'cyl',
    bw=True
)
